# %% [markdown]
# <font color = green >
#
#
# # Clustering part 2: Hierarchical clusterins and DBSCAN
#
# </font>

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# <font color = green >
#
# ## Home Task
#
# </font>
#
# Apply various clustering algorithms
#
# - Agglomerative clustering using `complete` linkage
# - Agglomerative clustering using `single` linkage
# - DBSCAN
# - Use albow methiod to determine the best k for Kmeans

# %%
clf = AgglomerativeClustering(n_clusters=5, linkage= 'single') 
predicted = clf.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c= colors[predicted], marker= '.') 
plt.title ('sklearn single')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.0, 'sklearn single')

# %%
clf = AgglomerativeClustering(n_clusters=5, linkage= 'complete') 
predicted = clf.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c= colors[predicted], marker= '.') 
plt.title ('sklearn complete')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.0, 'sklearn complete')

# %%
clf = DBSCAN(eps=0.9, min_samples=10).fit(X)
predicted = clf.labels_

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c= colors[predicted], marker= '.') 
plt.title ('sklearn DBSCAN')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.0, 'sklearn DBSCAN')

# %%
from sklearn.cluster import KMeans

# %%
J=[]
for number_claster in range(3,20):
    clf= KMeans(n_clusters=number_claster,n_init=10).fit(X)
    J_best=clf.inertia_
    J.append([number_claster,J_best])
print(J)
J = np.array(J)
# Out:
# [[3, 1646.0255144100242], [4, 787.0676994559476], [5, 343.87590333156646], [6, 314.5420823537092], [7, 289.07430196210333], [8, 268.03975265548655], [9, 244.2825966668687], [10, 221.45673623071707], [11, 204.71994888682084], [12, 184.7366849479471], [13, 170.1096804358433], [14, 156.0825982973459], [15, 147.87766932177954], [16, 137.87261319230953], [17, 130.91104970130925], [18, 123.65946633014288], [19, 119.75128113836104]]

# %%
plt.figure ()
plt.plot(J[:,0],J[:,1])
plt.xlabel('Iterations')
plt.ylabel('Cost function J')
plt.scatter(J[:,0],J[:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## The best number of clusters is 5 by Elbow method

# %%
clf= KMeans(n_clusters=5,n_init=10).fit(X)
print ('Cenroids:')
centroids = clf.cluster_centers_  
predicted = clf.predict(X)
plt.figure()
colors = np.array(['green','orange','grey', 'brown','yellow','black'])

# draw samples 
plt.scatter(X[:,0],X[:,1], c= colors[predicted])

# draw centroids 
for i, c in enumerate (clf.cluster_centers_):    
    plt.plot(c[0], c[1], marker = 'x', color= colors[i+1], markersize=14)
# Out:
# Cenroids:
# <img src="data:image/png;base64,..." width="640">

# %%
clf= KMeans(n_clusters=4,n_init=10).fit(X)
print ('Cenroids:')
centroids = clf.cluster_centers_  
predicted = clf.predict(X)
plt.figure()
colors = np.array(['green','orange','grey', 'brown','yellow','black'])

# draw samples 
plt.scatter(X[:,0],X[:,1], c= colors[predicted])

# draw centroids 
for i, c in enumerate (clf.cluster_centers_):    
    plt.plot(c[0], c[1], marker = 'x', color= colors[i+1], markersize=14)
# Out:
# Cenroids:
# <img src="data:image/png;base64,..." width="640">
