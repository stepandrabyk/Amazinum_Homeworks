# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Simple Line Plots

# %%
spotify_data = pd.read_csv("./data/spotify.csv", index_col="Date", parse_dates=True)

# %%
spotify_data.sample(10)
# Out:
#             Shape of You   Despacito  Something Just Like This     HUMBLE.  \
# Date
# 2017-07-30       5438809  11842229.0                 3485531.0   3603193.0
# 2017-04-28      10818508  20021846.0                 7545200.0  10309105.0
# 2017-08-10       5609356  11077073.0                 3704051.0   3861148.0
# 2017-02-14      15008480   7352353.0                       NaN         NaN
# 2017-07-14       6873986  16471127.0                 4727981.0   4588352.0
# 2017-10-04       4271413   4817960.0                 2572763.0   3144219.0
# 2017-12-23       4392917   3332468.0                 1827557.0   2317933.0
# 2017-12-08       4923111   4094943.0                 2574826.0   3035211.0
# 2017-11-27       3651453   2590998.0                 1855624.0   1945191.0
# 2017-03-28      13350066   6292943.0                 7690071.0         NaN
#
#             Unforgettable
# Date
# 2017-07-30      6310817.0
# 2017-04-28      3028343.0
# 2017-08-10      6834501.0
# 2017-02-14            NaN
# 2017-07-14      7428439.0
# 2017-10-04      5069708.0
# 2017-12-23      2372778.0
# 2017-12-08      3379843.0
# 2017-11-27      3091897.0
# 2017-03-28            NaN

# %%
plt.figure(figsize=(10,5))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data);

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date");

# %%
plt.figure(figsize=(16,6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data[['Shape of You', 'Despacito']]);

# %% [markdown]
# ### Bar Charts and Heatmaps

# %%
df_flights = pd.read_csv("./data/flight_delays.csv", index_col="Month")

# %%
df_flights
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
#              HA         MQ         NK         OO         UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894   6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895   7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693   4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796   4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162   6.827695  0.681605
# 6      0.882786   9.639323  35.561501   8.338477  16.932663  5.766296
# 7      2.001586   3.980289  14.352382   6.790333  10.262551       NaN
# 8      7.448029   1.896565  20.519018   5.606689   5.014041       NaN
# 9      3.696915  -2.167268   8.000101   1.530896  -1.794265       NaN
# 10     0.467074  -3.735054   6.810736   1.750897  -2.456542       NaN
# 11    -2.719894   0.220061   7.543881   4.925548   0.281064       NaN
# 12    -1.706475   0.662486  12.733123  10.947612   7.012079       NaN
#
#               VX         WN
# Month
# 1       1.420702   3.389466
# 2       7.784410   3.501363
# 3       5.348207   3.263341
# 4       0.995507   2.996399
# 5       7.102021   5.680777
# 6       5.779415  10.743462
# 7       7.135773  10.504942
# 8       5.106221   5.532108
# 9       0.070998  -1.336260
# 10      2.254278  -0.688851
# 11      0.116370   0.995684
# 12     13.498720   6.720893

# %% [markdown]
# We'd like to create a bar chart showing the average arrival delay for United Airlines (airline code: UA) flights, by month.

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Add title
plt.title("Average Arrival Delay for United Airlines Flights, by Month")

# Bar chart showing average arrival delay for United Airlines flights by month
sns.barplot(x=df_flights.index, y=df_flights['UA'])

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)");

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,8))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=df_flights, annot=True, linewidths=0.1, cmap="rocket")

# Add label for horizontal axis
plt.xlabel("Airline code");

# %% [markdown]
# # Plotly

# %% [markdown]
# ### What is Plotly
#
# * A powerful JavaScript graphing library
#     * No worries - no need to know JavaScript
#
# ### Main advantages:
# * Fast and easy to implement simple plots
# * Low code/low effort options using plotly.express
# * Extremely customizable
# * Interactive plots by default
#
# ### Creating Plotly Figures:
# * With plotly.express (px) for simple, quick plots
# * With plotly.graph_objects (go) for more customization
# * With plotly.figure_factory for specific, advanced figures
#
#
# #### Plotly figure has 3 main components:
# * <b>layout</b> - Dictionary controlling style of the fugure
#     * One <b>layout</b> per figure
# * <b>data</b> - List of dictionaries setting the graph type and data itself
#     * Data + type = <b>trace</b>
#     * Can have multiple traces per graph
# * <b>frames</b> - For animated plots

# %% [markdown]
# ### Imports

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from plotly) (8.1.0)

# %%
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import widgets

# %% [markdown]
# Constructing the figure from scratch:

# %%
figure_config = {
    "data": [
        {
            "type": "bar",
            "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
            "y": [28, 27, 25, 31, 32, 35, 36]
        }
    ],
    "layout": {
        "title": {
            "text": "Temperatures of the week",
            "x": 0.5,
            "font": {
                "color": "red",
                "size": 20
            }
        }
    }
}

fig = go.Figure(figure_config)
fig.show()
# Out:
# <div>                            <div id="6674843b-d047-4baa-a572-b321b6fe57fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6674843b-d047-4baa-a572-b321b6fe57fe")) {                    Plotly.newPlot(                        "6674843b-d047-4baa-a572-b321b6fe57fe",                        [{"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[28,27,25,31,32,35,36],"type":"bar"}],                        {"title":{"font":{"color":"red","size":20},"text":"Temperatures of the week","x":0.5},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}] ...
#
# var gd = document.getElementById('6674843b-d047-4baa-a572-b321b6fe57fe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!di

# %% [markdown]
# ### Bar Charts

# %%
df_temps = pd.DataFrame({
    "day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "temp": [28, 27, 25, 31, 32, 35, 36]
})

df_temps
# Out:
#          day  temp
# 0     Monday    28
# 1    Tuesday    27
# 2  Wednesday    25
# 3   Thursday    31
# 4     Friday    32
# 5   Saturday    35
# 6     Sunday    36

# %%
fig = px.bar(data_frame=df_temps, x="day", y="temp", title="Temperatures of the week")
fig.show()
# Out:
# <div>                            <div id="c5dac08e-2d0e-4d20-bd8b-978304f03ab6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5dac08e-2d0e-4d20-bd8b-978304f03ab6")) {                    Plotly.newPlot(                        "c5dac08e-2d0e-4d20-bd8b-978304f03ab6",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>temp=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"xaxis":"x","y":[28,27,25,31,32,35,36],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type" ...

# %% [markdown]
# ### Line plots

# %%
fig = px.line(spotify_data)
fig.update_yaxes({"title":"Amount of listens"})
fig.show()
# Out:
# <div>                            <div id="01d41244-cde6-45ff-bb3c-b0f3679df1ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d41244-cde6-45ff-bb3c-b0f3679df1ef")) {                    Plotly.newPlot(                        "01d41244-cde6-45ff-bb3c-b0f3679df1ef",                        [{"hovertemplate":"variable=Shape of You<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Shape of You","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Shape of You","showlegend":true,"x":["2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-04T00:00:00","2017-03-05T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-11T00:00:00","2017-03-12T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-18T00:00:00","2017-03-19T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-25T00:00:00","2017-03-26T00:00:00","2017-03-27T00:00:00","2017-03-28T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-01T00:00:00","2017-04-02T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-08T00:00:00","2017-04-09T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-14T00:00:00","2017-04-15T00:00:00","2017-04-16T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-22T00:00:00","2017-04-23T00:00:00","2017-04-24T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-04-29T00:00:00","2017-04-30T00:00:00","2017-05-01T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-06T00:00:00","2017-05-07T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-11T00:00:00","2017-05-12T00:00:00","2017-05-13T00:00:00","2017-05-14T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-20T00:00:00","2017-05-21T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-25T00:00:00","2017-05-26T00:00:00","2017-05-27T00:00:00","2017-05-28T00:00:00","2017-05-29T00:00:00","2017-06-01T00:00:00","2017-06-03T00:00:00","2017-06-04T00 ...

# %% [markdown]
# ### Histogram

# %%
import numpy as np
normal_distribution = np.random.randn(10000)

fig = px.histogram(normal_distribution, nbins=40)
fig.show()
# Out:
# <div>                            <div id="555a5ff5-49f0-444d-8f7b-b6e56182d5d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("555a5ff5-49f0-444d-8f7b-b6e56182d5d1")) {                    Plotly.newPlot(                        "555a5ff5-49f0-444d-8f7b-b6e56182d5d1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","nbinsx":40,"offsetgroup":"0","orientation":"v","showlegend":true,"x":[-2.0433926987199316,-0.6759218766065492,-0.9904515731423026,-1.7176754914864465,-1.3919922887756022,-0.5267947131009739,0.01089616687451936,0.841209266652672,-0.17025589184856774,0.3422435949853302,0.8458797995839942,0.674347991075231,-1.1198600038363076,-1.1749817259746793,1.219760714809431,-0.4678742286706622,0.23703862785822574,-0.9024858085715518,0.466086656089059,1.745692045460692,-1.5935429230672913,-0.0644038093072033,2.2877507636972276,0.273954085306981,1.020324929796101,-0.3843665955567234,-1.36749641506539,0.4954106603780256,-0.5507620182502354,-0.1305398285181419,0.0395938249668232,-0.5444151219901965,0.8495664746636762,0.4669571825472787,1.3932640627238864,-1.1353493817032492,-0.385123035154746,-1.56210252130767,0.04024886771682844,1.0782447490037583,1.1697765429490614,-2.1522588851545863,-0.45692463038607767,-1.0183572950505992,1.1535778908682695,-0.8580315425613275,-0.5875774208777582,0.7574199070062732,-0.7743849992711368,-2.208070779663069,1.202219936035373,-0.41182332151795803,-0.5661370649744454,-1.3017469359686002,1.144230244877506,0.9462904539103202,-0.05101934786752161,-1.9973273797231683,-0.3800627104352857,0.9412447307632346,-1.2599216626566883,-0.4586871592498188,1.631710101861815,0.002580899139135984,-1.0268193016162181,-0.5023833122358582,-1.1130728553909623,-0.36050119072886505,-0.03178987733399542,-0.3969790492339681,-0.13142191653884547,-0.2252815856839278,-0.9002939578572813,-0.6272282054964268,1.1083353421490751,0.07751254956950755,-0.6898718039914075,-0.47007356095133385,-2.1085509575779544,-0.20581367141399462,1.435954602124475,-1.681347419551967,-1.315025476729674,0.06290603743641883,-0.002518302867584476,-0.3808777572543518,-0.10382606746801672,-0.011889364980162622,-0.848585472677251,0.3687360558692605,0.5376621599621354,-1.137558829344385,-1.2651175768833227,1.0845470094795084,0.43418645128721395,-0.015678825048911865,-0.03335915230000827,-0.3834063925283705,1.7984860132677867,0.6219436022320333,-0.455204127648879,0.7518845923320623,1.2340757559971673,-0.8686648516261664,0.03205403051805222,-0.27268537038934,1.4426844794505542,-0.7924198088526334,-1.2444471955939163,0.96884688709535,3.220082482590706,-1.088055243004094,-1.6866657830581842,-0.5705253286263969,0.4813610051387499,-1.034499048337747,-0.6320065051752213,-0.17379810648618604,-0.3933427790438834,-0.33291012061423075,-0.8703655480237886,0.6053042833016654,3.5798540022250758,0.024123869388394496,-1.0496183665401477,0.850318807297184,-1.0755929501466361,-1.1416324440451526,0.6132446845143831,0.5926293673168093,-1.228776805424412,-2.196384773274093,0.36366202433597705,-0.4731125228538012,0.5715062303616626,0.7971709592665739,-0.5680099752347447,-0.9828961090223328,-0.5304532684431645,-0.39656802299221994,-1.295705798111704,0.22123113204447237,-0.3525636440308543,-0.4157233593757221,0.08915504253731359,-0.8029334372044232,-0.08206773998461675,-1.241148622559599,-0.41383302466645033,-1.1048864614782423,1.2727047637143296,0.8247495515092593,-2.1704994670690736,-0.7203537681463308,-0.6657670552083567,0.37780681180444686,1.6761297135563045,0.123928582375502,-1.3342569760134206,-0.6583432721831644,-0.8496771098350241,1.01674192997215,-0.0889852205014791,-0.4965 ...

# %% [markdown]
# ### Box plots

# %%
trace = go.Box(x=df_flights['UA'], name="Disctribution", fillcolor='navy')
data = [trace]
fig = go.Figure(data)
fig.show()
# Out:
# <div>                            <div id="99bcc700-ebc3-42df-a72f-10ab35cc3c67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99bcc700-ebc3-42df-a72f-10ab35cc3c67")) {                    Plotly.newPlot(                        "99bcc700-ebc3-42df-a72f-10ab35cc3c67",                        [{"fillcolor":"navy","name":"Disctribution","x":[6.352728635280893,7.260661890139884,4.892211518275757,4.376092010277744,6.827694692686485,16.932662867359483,10.262550955899984,5.014040631049598,-1.794264698812557,-2.4565417286977844,0.2810635476844398,7.0120787705033605],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker ...
#
# var gd = document.getElementById('99bcc700-ebc3-42df-a72f-10ab35cc3c67');
# var x = new MutationObserver(function (mutations, obser

# %% [markdown]
# ### Pie charts

# %%
df = pd.read_csv('./data/nycflights.csv')
df = df.drop(df.columns[[0]], axis=1)

# %%
df.sample(5)
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 41027   2013     10   16     622.0       -7.0     852.0      -37.0      AA
# 237282  2013      6   17     833.0       93.0     934.0       83.0      EV
# 84770   2013     12    2    1557.0       -3.0    1841.0      -25.0      DL
# 92534   2013     12   11     622.0       -8.0     929.0       -6.0      UA
# 187238  2013      4   24    1153.0       -7.0    1305.0       -7.0      EV
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 41027   N3JUAA    1205    EWR  MIA     135.0      1085   6.0    22.0
# 237282  N15980    5819    EWR  MHT      40.0       209   8.0    33.0
# 84770   N3741S    2459    JFK  MCO     131.0       944  15.0    57.0
# 92534   N39726    1454    LGA  IAH     230.0      1416   6.0    22.0
# 187238  N18114    4179    EWR  BTV      46.0       266  11.0    53.0

# %%
dff = df['carrier'].value_counts()[:10]
dff = dff.append(pd.Series({"others": df['carrier'].value_counts()[10:].sum()}))
label = dff.index
size = dff.values

colors = ['skyblue', '#FEBFB3', '#96D38C', '#D0F9B1', 'gold', 'orange', 'lightgrey', 
          'lightblue','lightgreen','aqua']
trace = go.Pie(labels=label, values=size, marker=dict(colors=colors),hole = 0.2)

data = [trace]
layout = go.Layout(
    title='Airline distribution'
)

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10808\2454931858.py:2: FutureWarning:
#
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <div>                            <div id="6ce9247c-2007-48d9-9df7-76fa3066f983" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ce9247c-2007-48d9-9df7-76fa3066f983")) {                    Plotly.newPlot(                        "6ce9247c-2007-48d9-9df7-76fa3066f983",                        [{"hole":0.2,"labels":["UA","B6","EV","DL","AA","MQ","US","9E","WN","VX","others"],"marker":{"colors":["skyblue","#FEBFB3","#96D38C","#D0F9B1","gold","orange","lightgrey","lightblue","lightgreen","aqua"]},"values":[58665,54635,54173,48110,32729,26397,20536,18460,12275,5162,5634],"type":"pie"}],                        {"title":{"text":"Airline distribution"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outli ...
#
# var gd = document.getElementById('6ce9247c-2007-48d9-9df7-76fa3066f983');
# var x =

# %%
dff = df['origin'].value_counts()
label = dff.index
size = dff.values

trace = go.Pie(labels=label, values=size, hole = 0.2)

data = [trace]
layout = go.Layout(
    title='Origin airport distribution'
)

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="1ca968f8-0c63-4a42-9b6e-9c17f593f8dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca968f8-0c63-4a42-9b6e-9c17f593f8dc")) {                    Plotly.newPlot(                        "1ca968f8-0c63-4a42-9b6e-9c17f593f8dc",                        [{"hole":0.2,"labels":["EWR","JFK","LGA"],"values":[120835,111279,104662],"type":"pie"}],                        {"title":{"text":"Origin airport distribution"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth" ...
#
# var gd = document.getElementById('1ca968f8-0c63-4a42-9b6e-9c17f593f8dc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!

# %% [markdown]
# ### Widgets

# %%
month = widgets.IntSlider(
    value=1.0,
    min=1.0,
    max=12.0,
    step=1.0,
    description='Month:',
    continuous_update=False
)

use_date = widgets.Checkbox(
    description='Consider date',
    value=True,
)

container = widgets.HBox(children=[use_date, month])

textbox = widgets.Dropdown(
    description='Airline:   ',
    value='DL',
    options=df['carrier'].unique().tolist()
)

origin = widgets.Dropdown(
    options=list(df['origin'].unique()),
    value='LGA',
    description='Origin Airport:',
)


# Assign an empty figure widget with two traces
trace1 = go.Histogram(x=df['arr_delay'], opacity=0.75, name='Arrival Delays')
trace2 = go.Histogram(x=df['dep_delay'], opacity=0.75, name='Departure Delays')
g = go.FigureWidget(data=[trace1, trace2],
                    layout=go.Layout(
                        title=dict(
                            text='NYC FlightDatabase'
                        ),
                        barmode='overlay'
                    ))

# %%
def validate():
    if origin.value in df['origin'].unique() and textbox.value in df['carrier'].unique():
        return True
    else:
        return False


def response(change):
    if validate():
        if use_date.value:
            filter_list = [i and j and k for i, j, k in
                           zip(df['month'] == month.value, df['carrier'] == textbox.value,
                               df['origin'] == origin.value)]
            temp_df = df[filter_list]

        else:
            filter_list = [i and j for i, j in
                           zip(df['carrier'] == 'DL', df['origin'] == origin.value)]
            temp_df = df[filter_list]
        x1 = temp_df['arr_delay']
        x2 = temp_df['dep_delay']
        with g.batch_update():
            g.data[0].x = x1
            g.data[1].x = x2
            g.layout.barmode = 'overlay'
            g.layout.xaxis.title = 'Delay in Minutes'
            g.layout.yaxis.title = 'Number of Delays'


origin.observe(response, names="value")
textbox.observe(response, names="value")
month.observe(response, names="value")
use_date.observe(response, names="value")

# %%
container2 = widgets.HBox([origin, textbox])
widgets.VBox([container,
              container2,
              g])
# Out:
# VBox(children=(HBox(children=(Checkbox(value=True, description='Consider date'), IntSlider(value=1, continuous…

# %% [markdown]
# ### What have you learned?
#
#
# Since it's not always easy to decide how to best tell the story behind your data, we've broken the chart types into three broad categories to help with this.
#
# <b>Trends</b> - A trend is defined as a pattern of change.
# * Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# <b>Relationship</b> - There are many different chart types that you can use to understand relationships between variables in your data.
# * Bar charts are useful for comparing quantities corresponding to different groups.
# * Heatmaps can be used to find color-coded patterns in tables of numbers.
# * Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#
# <b>Distribution</b> - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
# * Histograms show the distribution of a single numerical variable.
# * Box plots show demographic representation of numerical data through their quartiles

# %% [markdown]
# # Homework

# %%
df_data = pd.read_csv("./data/shootings.csv", index_col="id").reset_index(drop=True)

# %%
df_data.head()
# Out:
#                  name        date   manner_of_death       armed   age gender  \
# 0          Tim Elliot  2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category
# 0  Not fleeing        False                   Guns
# 1  Not fleeing        False                   Guns
# 2  Not fleeing        False                Unarmed
# 3  Not fleeing        False  Other unusual objects
# 4  Not fleeing        False       Piercing objects

# %%
df_tmp = df_data["gender"].value_counts()
df_tmp = df_tmp.to_frame().reset_index()
df_tmp.columns = ["gender", "count"]
fig = px.bar(df_tmp, x="gender", y="count", color="gender", title="Distribution of shootings by gender")
fig.show()
# Out:
# <div>                            <div id="1522d783-ffbc-42ce-bac5-48b3dadce804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1522d783-ffbc-42ce-bac5-48b3dadce804")) {                    Plotly.newPlot(                        "1522d783-ffbc-42ce-bac5-48b3dadce804",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>count=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["M"],"xaxis":"x","y":[4673],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>count=%{y}<extra></extra>","legendgroup":"F","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["F"],"xaxis":"x","y":[222],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"li ...

# %%
sns.countplot(x=df_data["gender"]).set(title="Distribution of shootings by gender")
# Out:
# [Text(0.5, 1.0, 'Distribution of shootings by gender')]

# %%
label = df_tmp["gender"]
size = df_tmp["count"]

trace = go.Pie(labels=label, values=size, hole = 0.2)

data = [trace]
layout = go.Layout(
    title='Distribution of shootings by gender'
)

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="6028d9d6-ec2a-4337-ab00-56a67b21ccb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6028d9d6-ec2a-4337-ab00-56a67b21ccb7")) {                    Plotly.newPlot(                        "6028d9d6-ec2a-4337-ab00-56a67b21ccb7",                        [{"hole":0.2,"labels":["M","F"],"values":[4673,222],"type":"pie"}],                        {"title":{"text":"Distribution of shootings by gender"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...
#
# var gd = document.getElementById('6028d9d6-ec2a-4337-ab00-56a67b21ccb7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);

# %%
plt.figure(figsize=(16,6))
palette_color = sns.color_palette('bright')
plt.pie(df_tmp['count'],labels=df_tmp['gender'],colors=palette_color,autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x16f034a4ac0>,
#   <matplotlib.patches.Wedge at 0x16f034b40d0>],
#  [Text(-1.0888537659492934, 0.15619691539221126, 'M'),
#   Text(1.0888537659492934, -0.15619691539221137, 'F')],
#  [Text(-0.5939202359723418, 0.08519831748666067, '95%'),
#   Text(0.5939202359723418, -0.08519831748666074, '5%')])
